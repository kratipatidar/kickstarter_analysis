# %%
#importing libraries

from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
import glob
import matplotlib.ticker as tick

# %%
# reading in all the folder locations

jan20_mar21_folders = []
for x in os.walk('/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020'):
    jan20_mar21_folders.append(x[0])
jan20_mar21_folders.pop(0)

# sorting to get locations chronologically
jan20_mar21_folders.sort()
jan20_mar21_folders
# Out:
# ['/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-01-16T03_20_15_556Z',
#  '/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-02-13T03_20_04_893Z',
#  '/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-03-12T03_20_06_551Z',
#  '/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-04-16T03_20_04_541Z',
#  '/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-05-14T03_20_08_560Z',
#  '/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-06-18T03_20_07_487Z',
#  '/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-07-16T03_20_08_086Z',
#  '/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-08-13T03_20_17_470Z',
#  '/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/kickstarter_2020/Kickstarter_2020-09-17T03_20_18_143Z',
# ...

# %%
# defining a function for reading in all the csv files, combining and pre-processing them

def month_df(folder_location):
    csv_files = []
    month_files = glob.glob(folder_location + '/*.csv')
    for file in month_files:
        csv_files.append(pd.read_csv(file))
    df = pd.concat(csv_files, axis=0, ignore_index = True)
    df['created_at'] = pd.to_datetime(df['created_at'],unit='s')
    df['state_changed_at'] = pd.to_datetime(df['state_changed_at'],unit='s')
    df['launched_at'] = pd.to_datetime(df['launched_at'],unit='s')
    return df

# %%
# building jan 20 df
jan_20 = month_df(jan20_mar21_folders[0])

# filtering based on jan 20 dates, eliminating all records before Jan 1, 2020
jan20 = jan_20[(jan_20['launched_at'] >= '2020-01-01') & (jan_20['launched_at'] <= '2020-01-31')]

# %%
# building feb 20 df
feb_20 = month_df(jan20_mar21_folders[1])

# filtering based on feb 20 dates
feb20 = feb_20[(feb_20['launched_at'] >= '2020-01-01') & (feb_20['launched_at'] <= '2020-02-29')]

# %%
# building mar 20 df
mar_20 = month_df(jan20_mar21_folders[2])

# filtering based on mar 20 dates
mar20 = mar_20[(mar_20['launched_at'] >= '2020-01-01') & (mar_20['launched_at'] <= '2020-03-31')]

# %%
# building apr 20 df
apr_20 = month_df(jan20_mar21_folders[3])

# filtering based on apr 20 dates
apr20 = apr_20[(apr_20['launched_at'] >= '2020-01-01') & (apr_20['launched_at'] <= '2020-04-30')]

# %%
# building may 20 df
may_20 = month_df(jan20_mar21_folders[4])

# filtering based on may 20 dates
may20 = may_20[(may_20['launched_at'] >= '2020-01-01') & (may_20['launched_at'] <= '2020-05-31')]

# %%
# building jun 20 df
jun_20 = month_df(jan20_mar21_folders[5])

# filtering based on jun 20 dates
jun20 = jun_20[(jun_20['launched_at'] >= '2020-01-01') & (jun_20['launched_at'] <= '2020-06-30')]

# %%
# building jul 20 df
jul_20 = month_df(jan20_mar21_folders[6])

# filtering based on jul 20 dates
jul20 = jul_20[(jul_20['launched_at'] >= '2020-01-01') & (jul_20['launched_at'] <= '2020-07-31')]

# %%
# building aug 20 df
aug_20 = month_df(jan20_mar21_folders[7])

# filtering based on aug 20 dates
aug20 = aug_20[(aug_20['launched_at'] >= '2020-01-01') & (aug_20['launched_at'] <= '2020-08-31')]

# %%
# building sep 20 df
sep_20 = month_df(jan20_mar21_folders[8])

# filtering based on sep 20 dates
sep20 = sep_20[(sep_20['launched_at'] >= '2020-01-01') & (sep_20['launched_at'] <= '2020-09-30')]

# %%
# building oct 20 df
oct_20 = month_df(jan20_mar21_folders[9])

# filtering based on oct 20 dates
oct20 = oct_20[(oct_20['launched_at'] >= '2020-01-01') & (oct_20['launched_at'] <= '2020-10-31')]

# %%
# building nov 20 df
nov_20 = month_df(jan20_mar21_folders[10])

# filtering based on nov 20 dates
nov20 = nov_20[(nov_20['launched_at'] >= '2020-01-01') & (nov_20['launched_at'] <= '2020-11-30')]

# %%
# building dec 20 df
dec_20 = month_df(jan20_mar21_folders[11])

# filtering based on nov 20 dates
dec20 = dec_20[(dec_20['launched_at'] >= '2020-01-01') & (dec_20['launched_at'] <= '2020-12-31')]

# %%
# building jan 21 df
jan_21 = month_df(jan20_mar21_folders[12])

# filtering based on nov 20 dates
yr_20_1 = jan_21[(jan_21['launched_at'] >= '2020-01-01') & (jan_21['launched_at'] <= '2020-12-31')]

# %%
# building feb 21 df
feb_21 = month_df(jan20_mar21_folders[13])

# filtering based on nov 20 dates
yr_20_2 = feb_21[(feb_21['launched_at'] >= '2020-01-01') & (feb_21['launched_at'] <= '2020-12-31')]

# %%
# building mar 21 df
mar_21 = month_df(jan20_mar21_folders[14])

# filtering based on nov 20 dates
yr_20_3 = mar_21[(mar_21['launched_at'] >= '2020-01-01') & (mar_21['launched_at'] <= '2020-12-31')]

# %%
# making a list out of all the dataframes
dfs_20 = [jan20, feb20, mar20, apr20, may20, jun20, jul20, aug20, 
       sep20, oct20, nov20, dec20, yr_20_1, yr_20_2, yr_20_3]

# %%
# combining the filtered dataframes into one dataframe
jan20_dec20= pd.concat(dfs_20, axis=0, ignore_index=True)
jan20_dec20
# Out:
#         backers_count                                              blurb  \
# 0                   2                             A YouTube Cooking Show
# 1                   2  Un libro sobre delirios paranoicos que pretend...
# 2                   7  A compilation of works completed for the 2019 ...
# 3                   7                        Fill your days with colors!
# 4                  14  Show your pride with the avenger's showing the...
# ...               ...                                                ...
# 368633           1455  An adult Visual Novel about a girl's adventure...
# 368634              7                 Marthaś Vineyards only mobile bar.
# 368635            159  Your support will fund a portion of our new ov...
# 368636            491  We hope CKB will be your family's go-to spot f...
# 368637            122  Unique immersion using a wearable VR controlle...
#
#                                                  category  \
# ...

# %%
# dropping columns with missing values for records
jan20_dec20_filt = jan20_dec20.drop(columns=['last_update_published_at', 'unread_messages_count',
       'unseen_activity_count'])
jan20_dec20_filt
# Out:
#         backers_count                                              blurb  \
# 0                   2                             A YouTube Cooking Show
# 1                   2  Un libro sobre delirios paranoicos que pretend...
# 2                   7  A compilation of works completed for the 2019 ...
# 3                   7                        Fill your days with colors!
# 4                  14  Show your pride with the avenger's showing the...
# ...               ...                                                ...
# 368633           1455  An adult Visual Novel about a girl's adventure...
# 368634              7                 Marthaś Vineyards only mobile bar.
# 368635            159  Your support will fund a portion of our new ov...
# 368636            491  We hope CKB will be your family's go-to spot f...
# 368637            122  Unique immersion using a wearable VR controlle...
#
#                                                  category  \
# ...

# %%
#splitting the source_url column to obtain different categories

jan20_dec20_filt['extracted_category']=jan20_dec20_filt['source_url'].str.split('/', expand=True)[5]
jan20_dec20_filt.head()
# Out:
#    backers_count                                              blurb  \
# 0              2                             A YouTube Cooking Show
# 1              2  Un libro sobre delirios paranoicos que pretend...
# 2              7  A compilation of works completed for the 2019 ...
# 3              7                        Fill your days with colors!
# 4             14  Show your pride with the avenger's showing the...
#
#                                             category  \
# 0  {"id":33,"name":"Webseries","slug":"film & vid...
# 1  {"id":50,"name":"Poetry","slug":"publishing/po...
# 2  {"id":22,"name":"Illustration","slug":"art/ill...
# 3  {"id":23,"name":"Painting","slug":"art/paintin...
# 4  {"id":262,"name":"Accessories","slug":"fashion...
#
#    converted_pledged_amount country country_displayable_name  \
# 0                      53.0      GB       the United Kingdom
# 1                      23.0      ES                    Spain
# ...

# %%
#replacing 'film%20&%20video' category with 'film and video'
jan20_dec20_filt = jan20_dec20_filt.replace('film%20&%20video', 'film and video')
jan20_dec20_filt.head()
# Out:
#    backers_count                                              blurb  \
# 0              2                             A YouTube Cooking Show
# 1              2  Un libro sobre delirios paranoicos que pretend...
# 2              7  A compilation of works completed for the 2019 ...
# 3              7                        Fill your days with colors!
# 4             14  Show your pride with the avenger's showing the...
#
#                                             category  \
# 0  {"id":33,"name":"Webseries","slug":"film & vid...
# 1  {"id":50,"name":"Poetry","slug":"publishing/po...
# 2  {"id":22,"name":"Illustration","slug":"art/ill...
# 3  {"id":23,"name":"Painting","slug":"art/paintin...
# 4  {"id":262,"name":"Accessories","slug":"fashion...
#
#    converted_pledged_amount country country_displayable_name  \
# 0                      53.0      GB       the United Kingdom
# 1                      23.0      ES                    Spain
# ...

# %%
# looking at duplicate records in the dataframe
duplicates = jan20_dec20_filt[jan20_dec20_filt.duplicated() == True]
duplicates
# Out:
#         backers_count                                              blurb  \
# 96515              62  A children's book dedicated to teaching the ru...
# 96751               1  Leather product’s ranging from dog jacket bags...
# 97024              24  The FlexiPec is a product designed for transma...
# 97098             101  Bringing the 1924 English translation of Knut ...
# 97237              39                                Creative Enamel Pin
# ...               ...                                                ...
# 122980             58                        A dystopian sci-fi novella.
# 122981              4  Help me finish the final steps in the publicat...
# 122983            151  A role playing game book and sequel to the suc...
# 122984            349  After a year of hard work we present to you Th...
# 123167              2  Estoy creando una marca de ropa de muy Alta Ca...
#
#                                                  category  \
# ...

# %%
# dropping duplicates across all the columns in the jan20_dec20_df dataframe 
jan20_dec20_df = jan20_dec20_filt.drop_duplicates(subset=None, keep='first', inplace=False)
jan20_dec20_df
# Out:
#         backers_count                                              blurb  \
# 0                   2                             A YouTube Cooking Show
# 1                   2  Un libro sobre delirios paranoicos que pretend...
# 2                   7  A compilation of works completed for the 2019 ...
# 3                   7                        Fill your days with colors!
# 4                  14  Show your pride with the avenger's showing the...
# ...               ...                                                ...
# 368633           1455  An adult Visual Novel about a girl's adventure...
# 368634              7                 Marthaś Vineyards only mobile bar.
# 368635            159  Your support will fund a portion of our new ov...
# 368636            491  We hope CKB will be your family's go-to spot f...
# 368637            122  Unique immersion using a wearable VR controlle...
#
#                                                  category  \
# ...

# %%
# writing the above dataframe to a csv

compression_opts = dict(method='zip',
                        archive_name='year_2020.csv')  
jan20_dec20_df.to_csv('year_2020.zip', index=False,
          compression=compression_opts)

# %%
# getting the counts of projects for each state

s = len(jan20_dec20_df.loc[jan20_dec20_df.state == 'successful'])
f = len(jan20_dec20_df.loc[jan20_dec20_df.state == 'failed'])
l = len(jan20_dec20_df.loc[jan20_dec20_df.state == 'live'])
c = len(jan20_dec20_df.loc[jan20_dec20_df.state == 'canceled'])
print(s,f,l,c)
# Out:
# 239657 50801 70314 7229

# %%
# making a dataframe to store these values

state_counts_20 = pd.DataFrame(columns=['success', 'failed', 'live', 'canceled'])
state_counts_20['success'] = [s]
state_counts_20['failed'] = f
state_counts_20['live'] = l
state_counts_20['canceled'] = c
state_counts_20
# Out:
#    success  failed   live  canceled
# 0   239657   50801  70314      7229

# %%
# Now, we will segregate this dataframe based on state of the projects. The successful and failed projects
##will form one dataframe which will be analyzed, and the live and canceled will form another dataframe.

jan20dec20_sf = jan20_dec20_df[(jan20_dec20_df['state']== 'successful') | (jan20_dec20_df['state']== 'failed')]
jan20dec20_sf
# Out:
#         backers_count                                              blurb  \
# 218                12  A bracelet with the final stats of this projec...
# 284                 4  A fun poster of my favorite film in chronologi...
# 362                20  Ginger KICK! goodies for cooking and eating, i...
# 424                81  A Make/100 project to build an adventure from ...
# 504                 1  2020 Uniquely Designed Presidential Candidates...
# ...               ...                                                ...
# 368633           1455  An adult Visual Novel about a girl's adventure...
# 368634              7                 Marthaś Vineyards only mobile bar.
# 368635            159  Your support will fund a portion of our new ov...
# 368636            491  We hope CKB will be your family's go-to spot f...
# 368637            122  Unique immersion using a wearable VR controlle...
#
#                                                  category  \
# ...

# %%
# Here, we store the live and canceled projects to another dataframe

jan20dec20_lc = jan20_dec20_df[(jan20_dec20_df['state']== 'live') | (jan20_dec20_df['state']== 'canceled')]
jan20dec20_lc
# Out:
#         backers_count                                              blurb  \
# 0                   2                             A YouTube Cooking Show
# 1                   2  Un libro sobre delirios paranoicos que pretend...
# 2                   7  A compilation of works completed for the 2019 ...
# 3                   7                        Fill your days with colors!
# 4                  14  Show your pride with the avenger's showing the...
# ...               ...                                                ...
# 368590              1  Eggsplict Content Coming Soon to Denver, CO\nB...
# 368593             10  Beekeepers actively saving honeybees with our ...
# 368604              2  An application where users get real rewards fo...
# 368605              8                           Sliders & Co. Food Truck
# 368620             11  It takes 21 days to break a habit! \nJoin the ...
#
#                                                  category  \
# ...

# %%
# fixing the names of countries for matching purposes later on

jan20dec20_sf = jan20dec20_sf.replace('the United States', 'United States')
jan20dec20_sf = jan20dec20_sf.replace('the United Kingdom', 'United Kingdom')
jan20dec20_sf = jan20dec20_sf.replace('the Netherlands', 'Netherlands')

# %%
# resetting the index for writing to a csv

jan20dec20_sf.reset_index(inplace=True)
jan20dec20_sf.head()
# Out:
#   launched_at  backers_count  \
# 0  2020-01-03             12
# 1  2020-01-01              4
# 2  2020-01-06             20
# 3  2020-01-02             81
# 4  2020-01-05              1
#
#                                                blurb  \
# 0  A bracelet with the final stats of this projec...
# 1  A fun poster of my favorite film in chronologi...
# 2  Ginger KICK! goodies for cooking and eating, i...
# 3  A Make/100 project to build an adventure from ...
# 4  2020 Uniquely Designed Presidential Candidates...
#
#                                             category  \
# 0  {"id":7,"name":"Design","slug":"design","posit...
# 1  {"id":27,"name":"Graphic Design","slug":"desig...
# 2  {"id":313,"name":"Small Batch","slug":"food/sm...
# 3  {"id":34,"name":"Tabletop Games","slug":"games...
# 4  {"id":263,"name":"Apparel","slug":"fashion/app...
#
#    converted_pledged_amount country country_displayable_name  \
# 0                      66.0      US            United States
# ...

# %%
# writing the above dataframe to a csv

jan20dec20_sf.to_csv('year_2020_sf.csv', index=False)

# %%
###### reading in the file as kernel died in between

jan20dec20_sf = pd.read_csv('year_2020_sf.csv')
jan20dec20_sf.head()
# Out:
# /Users/kratipatidar/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (15,19,21,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   launched_at  backers_count  \
# 0  2020-01-03             12
# 1  2020-01-01              4
# 2  2020-01-06             20
# 3  2020-01-02             81
# 4  2020-01-05              1
#
#                                                blurb  \
# 0  A bracelet with the final stats of this projec...
# 1  A fun poster of my favorite film in chronologi...
# 2  Ginger KICK! goodies for cooking and eating, i...
# 3  A Make/100 project to build an adventure from ...
# 4  2020 Uniquely Designed Presidential Candidates...
#
#                                             category  \
# 0  {"id":7,"name":"Design","slug":"design","posit...
# 1  {"id":27,"name":"Graphic Design","slug":"desig...
# ...

# %%
# plotting number of projects country-wise
p1 = pd.DataFrame(jan20dec20_sf.groupby('country_displayable_name')['blurb'].count()).reset_index()
# Use white grid plot background from seaborn
sns.set(font_scale=1, style="whitegrid")

#setting up plot
plt.figure(figsize=(5,5), dpi= 120)
plt.bar('country_displayable_name', 'blurb', data=p1)
plt.xlabel('Country')
plt.ylabel('Project Count')
plt.title('Project Count per Country')
plt.xticks(rotation='vertical')
plt.show()

# %%
# plotting number of projects category-wise
p2 = pd.DataFrame(jan20dec20_sf.groupby('extracted_category')['blurb'].count()).reset_index()

# Use white grid plot background from seaborn
sns.set(font_scale=1, style="whitegrid")

#setting up plot
plt.figure(figsize=(5,5), dpi= 120)
plt.bar('extracted_category', 'blurb', data=p2)
plt.xlabel('Category')
plt.ylabel('Project Count')
plt.title('Project Count per Category')
plt.xticks(rotation='vertical')
plt.show()

# %%
# converting dtype of 'launched_at' column from object to datetime type
jan20dec20_sf['launched_at'] = pd.to_datetime(jan20dec20_sf['launched_at'])

# looking at dtypes to verify
jan20dec20_sf.dtypes
# Out:
# launched_at                 datetime64[ns]
# backers_count                        int64
# blurb                               object
# category                            object
# converted_pledged_amount           float64
# country                             object
# country_displayable_name            object
# created_at                          object
# creator                             object
# currency                            object
# currency_symbol                     object
# currency_trailing_code                bool
# current_currency                    object
# deadline                             int64
# disable_communication                 bool
# friends                             object
# fx_rate                            float64
# goal                               float64
# id                                   int64
# is_backing                          object
# is_starrable                          bool
# is_starred                          object
# ...

# %%
# setting the index as launched_date for monthly grouping
jan20dec20_sf.set_index('launched_at', inplace=True)
jan20dec20_sf.head()
# Out:
#              backers_count                                              blurb  \
# launched_at
# 2020-01-03              12  A bracelet with the final stats of this projec...
# 2020-01-01               4  A fun poster of my favorite film in chronologi...
# 2020-01-06              20  Ginger KICK! goodies for cooking and eating, i...
# 2020-01-02              81  A Make/100 project to build an adventure from ...
# 2020-01-05               1  2020 Uniquely Designed Presidential Candidates...
#
#                                                       category  \
# launched_at
# 2020-01-03   {"id":7,"name":"Design","slug":"design","posit...
# 2020-01-01   {"id":27,"name":"Graphic Design","slug":"desig...
# 2020-01-06   {"id":313,"name":"Small Batch","slug":"food/sm...
# 2020-01-02   {"id":34,"name":"Tabletop Games","slug":"games...
# 2020-01-05   {"id":263,"name":"Apparel","slug":"fashion/app...
#
#              converted_pledged_amount country country_displayable_name  \
# launched_at
# ...

# %%
# grouping the dataframe monthly for plotting time series - for countries
monthly_20 = pd.DataFrame(jan20dec20_sf.groupby([pd.Grouper(freq='M'), 'country_displayable_name'])['blurb'].count()).reset_index()
monthly_20
# Out:
#     launched_at country_displayable_name  blurb
# 0    2020-01-31                Australia    945
# 1    2020-01-31                  Austria     85
# 2    2020-01-31                  Belgium    101
# 3    2020-01-31                   Canada   2404
# 4    2020-01-31                  Denmark    182
# ..          ...                      ...    ...
# 267  2020-12-31                    Spain    192
# 268  2020-12-31                   Sweden     76
# 269  2020-12-31              Switzerland     43
# 270  2020-12-31           United Kingdom    608
# 271  2020-12-31            United States   2919
#
# [272 rows x 3 columns]

# %%
# Getting unique countries
countries = list(monthly_20['country_displayable_name'].unique())
len(countries)
# Out:
# 25

# %%
# PLOTTING THE TIME SERIES

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

#setting up plot
plt.figure(figsize=(15,12), dpi= 120)

#function for plot
for i,c in enumerate(countries):
    plt.plot('launched_at', 'blurb', 
             data= monthly_20.loc[monthly_20.country_displayable_name == c, :],label=c)
    plt.legend(loc= 'best', bbox_to_anchor = (1,1))
    #locs, labels = xticks()
    plt.xticks(monthly_20['launched_at'].values, rotation='vertical')
    plt.xlabel('Date')
    plt.ylabel('Project Count')
    plt.title('Variation in Projects - Across Countries')

# %%
# grouping by categories
grouped_df_cat = pd.DataFrame(jan20dec20_sf.groupby([pd.Grouper(freq='M'), 'extracted_category'])['blurb'].count()).reset_index()
grouped_df_cat.head()
# Out:
#   launched_at extracted_category  blurb
# 0  2020-01-31                art   6519
# 1  2020-01-31             comics   3366
# 2  2020-01-31             crafts   1563
# 3  2020-01-31              dance    209
# 4  2020-01-31             design   3567

# %%
# Getting unique categories
categories = list(grouped_df_cat['extracted_category'].unique())
print(len(categories))
# Out:
# 15

# %%
# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

#setting up plot
plt.figure(figsize=(16,12), dpi= 120)

#function for plot
for i,c in enumerate(categories):
    plt.plot('launched_at', 'blurb', data= grouped_df_cat.loc[grouped_df_cat.extracted_category == c, :],label=c)
    plt.legend(loc= 'best', bbox_to_anchor = (1,1))
    #plt.ylim(0,500)
    plt.xticks(grouped_df_cat['launched_at'].values, rotation='vertical')
    plt.xlabel('Date')
    plt.ylabel('Project Count by Category')
    plt.title('Variation in Number of Projects - Across Categories')

# %%
# Getting unique states
states = list(jan20dec20_sf['state'].unique())
print(len(states))

#setting colors for categories
customcolors_state = {}
import numpy as np
mycolors = np.array(list(mpl.colors.XKCD_COLORS.keys()))
for x, color in zip(states,mycolors):
    customcolors_state[x] = color
customcolors_state = np.array(list(customcolors_state.values()))
print(customcolors_state)
# Out:
# 2
# ['xkcd:cloudy blue' 'xkcd:dark pastel green']

# %%
# looking at the different funding ranges, we will plot a bunch of graphs
## for eliminating redundancy, we will create a function for generating these graphs

def fr_plots(x,y):
    #dataframe subset with the required range
    fr_xy = pd.DataFrame(jan20dec20_sf[(jan20dec20_sf['goal'] > x) & (jan20dec20_sf['goal'] <= y)])
    #grouping for the first plot, we generate another dataframe
    fr_p1 = pd.DataFrame(fr_xy.groupby('state')['blurb'].count()).reset_index()
    # we plot this dataframe, which shows us the total number of successful and failed projects in our funding range
    plt.figure(figsize=(3,3), dpi= 120)
    plt.bar('state', 'blurb', data=fr_p1)
    plt.xlabel('State')
    plt.ylabel('Project Count')
    plt.title('Project Count per State')
    plt.xticks(rotation='vertical')
    plt.show()
    print(plt.show())
    # now for plotting the time-series, we will have to group by the original fr_xy
    fr_xy_grp = pd.DataFrame(fr_xy.groupby([pd.Grouper(freq='M'), 'state'])['blurb'].count()).reset_index()
    # Now we go on to plot the time-series
    # Handle date time conversions between pandas and matplotlib
    from pandas.plotting import register_matplotlib_converters
    register_matplotlib_converters()
    # Use white grid plot background from seaborn
    sns.set(font_scale=1.5, style="whitegrid")
    #setting up plot
    plt.figure(figsize=(5,5), dpi= 120)
    #function for plot
    for i,c in enumerate(states):
        plt.plot('launched_at', 'blurb', data= fr_xy_grp.loc[fr_xy_grp.state == c, :], color = customcolors_state[i],label=c)
        plt.legend(loc= 'best')
        #plt.ylim(0,500)
        plt.xticks(fr_xy_grp['launched_at'].values, rotation='vertical')
        plt.legend(loc= 'best', bbox_to_anchor = (1,1))
        plt.xlabel('Date')
        plt.ylabel('Project Count')
        plt.title('Failed and Successful Projects')
    # Now we will plot percentage of failed and successful projects over the different funding ranges
    ## first we create a dataframe for pivoting tables to calculate the percentage column
    fr_xy_pt = pd.pivot_table(fr_xy_grp, index='launched_at', columns = 'state', values = 'blurb')
    fr_xy_pt.reset_index(inplace=True)
    fr_xy_pt['failed_percent'] = (fr_xy_pt['failed']/(fr_xy_pt['failed']+fr_xy_pt['successful']))*100
    fr_xy_pt['success_percent'] = (fr_xy_pt['successful']/(fr_xy_pt['failed']+fr_xy_pt['successful']))*100
    #Plotting the failed and successful percentages
    ##failed %
    # Use white grid plot background from seaborn
    sns.set(font_scale=1, style="whitegrid")
    #setting up plot
    plt.figure(figsize=(3,3), dpi= 120)
    plt.plot('launched_at', 'failed_percent', data=fr_xy_pt)
    plt.xlabel('Date')
    plt.ylabel('Percentage of Failed Projects')
    plt.title('Variation in Percentage of Failed Projects')
    plt.xticks(fr_xy_pt['launched_at'].values, rotation='vertical')
    print(plt.show())

# %%
# plots for funding range less than 10k
fr_plots(0, 10000)
# Out:
# None
# None

# %%
# plots for funding range between 10 k and 100k
fr_plots(10000, 100000)
# Out:
# None
# None

# %%
# plots for funding range between 100k and 1M
fr_plots(100000, 1000000)
# Out:
# None
# None

# %%
# plots for funding range greater than 1M
fr_plots(1000000, 10000000)
# Out:
# None
# None

# %%
# Now we will read in the covid data file

covid_df = pd.read_csv('/Users/kratipatidar/Desktop/spring21_GA/prof_ahsan/covid_data.csv')
covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 80981      ZWE    Africa     Zimbabwe  2021-04-07      36984.0       18.0
# 80982      ZWE    Africa     Zimbabwe  2021-04-08      37052.0       68.0
# 80983      ZWE    Africa     Zimbabwe  2021-04-09      37147.0       95.0
# 80984      ZWE    Africa     Zimbabwe  2021-04-10      37273.0      126.0
# 80985      ZWE    Africa     Zimbabwe  2021-04-11      37288.0       15.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# let's convert the date column to datetime format

covid_df['date'] = pd.to_datetime(covid_df['date'])

# %%
# setting the date index

covid_df.set_index('date', inplace=True)

# %%
# grouping monthly

covid_monthly = pd.DataFrame(covid_df.groupby([pd.Grouper(freq='M'), 'location'])['new_cases_smoothed'].sum()).reset_index()
covid_monthly
# Out:
#            date   location  new_cases_smoothed
# 0    2020-01-31  Argentina               0.000
# 1    2020-01-31       Asia            3870.714
# 2    2020-01-31  Australia               1.286
# 3    2020-01-31   Cambodia               0.000
# 4    2020-01-31     Canada               0.571
# ...         ...        ...                 ...
# 2919 2021-04-30    Vietnam              78.143
# 2920 2021-04-30      World         6727753.285
# 2921 2021-04-30      Yemen            1066.428
# 2922 2021-04-30     Zambia            1686.143
# 2923 2021-04-30   Zimbabwe             265.857
#
# [2924 rows x 3 columns]

# %%
# checking for the countries in our monthly aggregated dataframe for projects
monthly_20['country_displayable_name'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Denmark', 'France',
#        'Germany', 'Hong Kong', 'Ireland', 'Italy', 'Japan', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Singapore',
#        'Spain', 'Sweden', 'Switzerland', 'United Kingdom',
#        'United States', 'Poland', 'Greece', 'Slovenia'], dtype=object)

# %%
# filtering the monthly covid dataframe on these countries
filt_covid = covid_monthly.loc[covid_monthly.location.isin(['Australia', 'Austria', 'Belgium', 'Canada', 'Denmark', 'France',
       'Germany', 'Hong Kong', 'Ireland', 'Italy', 'Japan', 'Luxembourg',
       'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Singapore',
       'Spain', 'Sweden', 'Switzerland', 'United Kingdom',
       'United States', 'Poland', 'Greece', 'Slovenia'])]
filt_covid
# Out:
#            date        location  new_cases_smoothed
# 2    2020-01-31       Australia               1.286
# 4    2020-01-31          Canada               0.571
# 10   2020-01-31          France               1.857
# 11   2020-01-31         Germany               0.000
# 12   2020-01-31       Hong Kong               0.000
# ...         ...             ...                 ...
# 2893 2021-04-30           Spain           70067.856
# 2897 2021-04-30          Sweden           59532.857
# 2898 2021-04-30     Switzerland           18914.570
# 2912 2021-04-30  United Kingdom           34328.571
# 2913 2021-04-30   United States          726355.571
#
# [385 rows x 3 columns]

# %%
# Now merging the dataframes for monthly project counts and monthly new covid cases

merged = pd.merge(monthly_20, filt_covid, how = 'inner', 
                  left_on = ['launched_at', 'country_displayable_name'], right_on= ['date', 'location'])
merged
# Out:
#     launched_at country_displayable_name  blurb       date        location  \
# 0    2020-01-31                Australia    945 2020-01-31       Australia
# 1    2020-01-31                   Canada   2404 2020-01-31          Canada
# 2    2020-01-31                   France    898 2020-01-31          France
# 3    2020-01-31                  Germany    891 2020-01-31         Germany
# 4    2020-01-31                Hong Kong    908 2020-01-31       Hong Kong
# ..          ...                      ...    ...        ...             ...
# 256  2020-12-31                    Spain    192 2020-12-31           Spain
# 257  2020-12-31                   Sweden     76 2020-12-31          Sweden
# 258  2020-12-31              Switzerland     43 2020-12-31     Switzerland
# 259  2020-12-31           United Kingdom    608 2020-12-31  United Kingdom
# 260  2020-12-31            United States   2919 2020-12-31   United States
#
#      new_cases_smoothed
# 0                 1.286
# ...

# %%
# renaming columns of the merged dataframe for sensible plotting

merged.rename(columns={'blurb': 'ProjectCount', 'new_cases_smoothed': 'NewCOVIDCases'}, inplace=True)

# %%
# Here, we make a function for plotting the project counts in each country with the new covid cases across time
## we can call this function for each country then, to look for trends

def combo_plots(country):
    # getting data for specific country
    con_data =  merged.loc[merged.location == country, :]
    # plotting
    # Use white grid plot background from seaborn
    sns.set(font_scale=1, style="whitegrid")
    #setting up plot
    fig = plt.figure(figsize=(7,5), dpi=120)
    ax1 = fig.add_subplot()
    ax2 = ax1.twinx()
    ax1.plot('date', 'ProjectCount', data=con_data, color='orange', label='ProjectCount')
    ax2.plot('date', 'NewCOVIDCases', data=con_data, color='purple', label='NewCOVIDCases')
    fig.legend(bbox_to_anchor = (1.24,.9))
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Project Count')
    ax2.set_ylabel('Number of New COVID Cases')
    ax1.set_title('Trend for {}'.format(country))
    ax1.set_xticks(con_data['date'].values)
    ax1.tick_params(labelrotation=60)
    
    # setting y-axis tickers (for covid cases) when value in millions
    def reformat_large_tick_values(tick_val, pos):
        if tick_val >= 1000000:
            val = round(tick_val/1000000, 2)
            new_tick_format = '{}M'.format(val)
            # make new_tick_format into a string value
            new_tick_format = str(new_tick_format)
            return new_tick_format
        
    # applying this fuction to actual values
    for x in con_data['NewCOVIDCases']:
        if x > 1000000:
            ax2.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
        else:
            pass
    
    fig.tight_layout()
    plt.show()

# %%
# calling the function for countries
combo_plots('New Zealand')

# %%
# now we group the dataframe by the state column in addition to the date and country column for further plotting
f_pc = pd.DataFrame(jan20dec20_sf.groupby([pd.Grouper(freq='M'), 'country_displayable_name', 'state'])['blurb'].count()).reset_index()
f_pc
# Out:
#     launched_at country_displayable_name       state  blurb
# 0    2020-01-31                Australia      failed    268
# 1    2020-01-31                Australia  successful    677
# 2    2020-01-31                  Austria      failed     14
# 3    2020-01-31                  Austria  successful     71
# 4    2020-01-31                  Belgium  successful    101
# ..          ...                      ...         ...    ...
# 519  2020-12-31              Switzerland  successful     34
# 520  2020-12-31           United Kingdom      failed     87
# 521  2020-12-31           United Kingdom  successful    521
# 522  2020-12-31            United States      failed    565
# 523  2020-12-31            United States  successful   2354
#
# [524 rows x 4 columns]

# %%
# pivoting the above table 
f_pc_pt = pd.pivot_table(f_pc, index=['launched_at', 'country_displayable_name'], columns = 'state', values = 'blurb')
f_pc_pt.reset_index(inplace=True)

#calculating the failed percentages
f_pc_pt['failed_percent'] = (f_pc_pt['failed']/(f_pc_pt['failed']+f_pc_pt['successful']))*100
f_pc_pt
# Out:
# state launched_at country_displayable_name  failed  successful  failed_percent
# 0      2020-01-31                Australia   268.0       677.0       28.359788
# 1      2020-01-31                  Austria    14.0        71.0       16.470588
# 2      2020-01-31                  Belgium     NaN       101.0             NaN
# 3      2020-01-31                   Canada   474.0      1930.0       19.717138
# 4      2020-01-31                  Denmark    26.0       156.0       14.285714
# ..            ...                      ...     ...         ...             ...
# 267    2020-12-31                    Spain    36.0       156.0       18.750000
# 268    2020-12-31                   Sweden    15.0        61.0       19.736842
# 269    2020-12-31              Switzerland     9.0        34.0       20.930233
# 270    2020-12-31           United Kingdom    87.0       521.0       14.309211
# 271    2020-12-31            United States   565.0      2354.0       19.355944
#
# [272 rows x 5 columns]

# %%
# merging the above table with the dataframe for covid cases

merged_2 = pd.merge(f_pc_pt, filt_covid, how = 'inner', 
                  left_on = ['launched_at', 'country_displayable_name'], right_on= ['date', 'location'])
merged_2
# Out:
#     launched_at country_displayable_name  failed  successful  failed_percent  \
# 0    2020-01-31                Australia   268.0       677.0       28.359788
# 1    2020-01-31                   Canada   474.0      1930.0       19.717138
# 2    2020-01-31                   France   106.0       792.0       11.804009
# 3    2020-01-31                  Germany   334.0       557.0       37.485971
# 4    2020-01-31                Hong Kong   116.0       792.0       12.775330
# ..          ...                      ...     ...         ...             ...
# 256  2020-12-31                    Spain    36.0       156.0       18.750000
# 257  2020-12-31                   Sweden    15.0        61.0       19.736842
# 258  2020-12-31              Switzerland     9.0        34.0       20.930233
# 259  2020-12-31           United Kingdom    87.0       521.0       14.309211
# 260  2020-12-31            United States   565.0      2354.0       19.355944
#
# ...

# %%
# renaming columns of the merged dataframe for sensible plotting

merged_2.rename(columns={'failed_percent': 'PercentageOfFailedProjects', 'new_cases_smoothed': 'NewCOVIDCases'}, inplace=True)

# %%
# Here, we make a function for plotting the percentage of failed in each country with the new covid cases across time
## we can call this function for each country then, to look for trends

def combo_plots_2(country):
    # getting data for specific country
    con_data =  merged_2.loc[merged_2.location == country, :]
    # plotting
    # Use white grid plot background from seaborn
    sns.set(font_scale=1, style="whitegrid")
    #setting up plot
    fig = plt.figure(figsize=(7,5), dpi=120)
    ax1 = fig.add_subplot()
    ax2 = ax1.twinx()
    ax1.plot('date', 'PercentageOfFailedProjects', data=con_data, color='red', label='PercentageOfFailedProjects')
    ax2.plot('date', 'NewCOVIDCases', data=con_data, color='purple', label='NewCOVIDCases')
    fig.legend(bbox_to_anchor = (1.34,.9))
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Percentage of Failed Projects')
    ax2.set_ylabel('Number of New COVID Cases')
    ax1.set_title('Trend for {}'.format(country))
    ax1.set_xticks(con_data['date'].values)
    ax1.tick_params(labelrotation=60)
    
    # setting y-axis tickers (for covid cases) when value in millions
    def reformat_large_tick_values(tick_val, pos):
        if tick_val >= 1000000:
            val = round(tick_val/1000000, 2)
            new_tick_format = '{}M'.format(val)
            # make new_tick_format into a string value
            new_tick_format = str(new_tick_format)
            return new_tick_format
        
    # applying this fuction to actual values
    for x in con_data['NewCOVIDCases']:
        if x > 1000000:
            ax2.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
        else:
            pass
    
    
    fig.tight_layout()
    plt.show()

# %%
# calling the function for countries
combo_plots_2('Singapore')

# %%
# now we will group the dataframe by category and state in addition to date
f_pcat = pd.DataFrame(jan20dec20_sf.groupby([pd.Grouper(freq='M'), 'extracted_category', 
                                             'country_displayable_name','state'])['blurb'].count()).reset_index()
f_pcat.head()
# Out:
#   launched_at extracted_category country_displayable_name       state  blurb
# 0  2020-01-31                art                Australia      failed     25
# 1  2020-01-31                art                Australia  successful     97
# 2  2020-01-31                art                  Belgium  successful     29
# 3  2020-01-31                art                   Canada      failed     86
# 4  2020-01-31                art                   Canada  successful    491

# %%
# pivoting the above table 
f_pcat_pt = pd.pivot_table(f_pcat, index=['launched_at', 'country_displayable_name', 
                                      'extracted_category'], columns = 'state', values = 'blurb')
f_pcat_pt.reset_index(inplace=True)

# calculating failed percent
f_pcat_pt['failed_percent'] = (f_pcat_pt['failed']/(f_pcat_pt['failed']+f_pcat_pt['successful']))*100
f_pcat_pt
# Out:
# state launched_at country_displayable_name extracted_category  failed  \
# 0      2020-01-31                Australia                art    25.0
# 1      2020-01-31                Australia             comics     NaN
# 2      2020-01-31                Australia             crafts    40.0
# 3      2020-01-31                Australia             design    14.0
# 4      2020-01-31                Australia            fashion    20.0
# ...           ...                      ...                ...     ...
# 2344   2020-12-31            United States              music    34.0
# 2345   2020-12-31            United States        photography     6.0
# 2346   2020-12-31            United States         publishing    56.0
# 2347   2020-12-31            United States         technology   160.0
# 2348   2020-12-31            United States            theater     2.0
#
# state  successful  failed_percent
# 0            97.0       20.491803
# 1            13.0             NaN
# ...

# %%
# merging the above table with the dataframe for covid cases

merged_3 = pd.merge(f_pcat_pt, filt_covid, how = 'inner', 
                  left_on = ['launched_at', 'country_displayable_name'], right_on= ['date', 'location'])
merged_3
# Out:
#      launched_at country_displayable_name extracted_category  failed  \
# 0     2020-01-31                Australia                art    25.0
# 1     2020-01-31                Australia             comics     NaN
# 2     2020-01-31                Australia             crafts    40.0
# 3     2020-01-31                Australia             design    14.0
# 4     2020-01-31                Australia            fashion    20.0
# ...          ...                      ...                ...     ...
# 2270  2020-12-31            United States              music    34.0
# 2271  2020-12-31            United States        photography     6.0
# 2272  2020-12-31            United States         publishing    56.0
# 2273  2020-12-31            United States         technology   160.0
# 2274  2020-12-31            United States            theater     2.0
#
#       successful  failed_percent       date       location  new_cases_smoothed
# ...

# %%
# renaming columns of the merged dataframe for sensible plotting

merged_3.rename(columns={'failed_percent': 'PercentageOfFailedProjects', 'new_cases_smoothed': 'NewCOVIDCases', 
                         'extracted_category': 'ProjectCategory'}, inplace=True)
merged_3
# Out:
#      launched_at country_displayable_name ProjectCategory  failed  successful  \
# 0     2020-01-31                Australia             art    25.0        97.0
# 1     2020-01-31                Australia          comics     NaN        13.0
# 2     2020-01-31                Australia          crafts    40.0        48.0
# 3     2020-01-31                Australia          design    14.0        76.0
# 4     2020-01-31                Australia         fashion    20.0       188.0
# ...          ...                      ...             ...     ...         ...
# 2270  2020-12-31            United States           music    34.0       134.0
# 2271  2020-12-31            United States     photography     6.0        42.0
# 2272  2020-12-31            United States      publishing    56.0       292.0
# 2273  2020-12-31            United States      technology   160.0       179.0
# 2274  2020-12-31            United States         theater     2.0         6.0
#
# ...

# %%
# Here, we make a function for plotting the percentage of failed in each country with the new covid cases across time
## we can call this function for each country then, to look for trends

def combo_plots_3(country, category):
    # getting data for specific country
    con_data =  merged_3.loc[merged_3.location == country, :]
    cat_data = con_data.loc[con_data.ProjectCategory == category, :]
    # plotting
    # Use white grid plot background from seaborn
    sns.set(font_scale=1.2, style="whitegrid")
    #setting up plot
    fig = plt.figure(figsize=(12,10), dpi=120)
    ax1 = fig.add_subplot()
    ax2 = ax1.twinx()
    ax1.plot('date', 'PercentageOfFailedProjects', 
                 data=cat_data, color='coral', label=category)
    ax2.plot('date', 'NewCOVIDCases', data=con_data, color='purple', label='NewCOVIDCases')
    fig.legend(bbox_to_anchor = (1.2, .9))
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Percentage of Failed Projects')
    ax2.set_ylabel('Number of New COVID Cases')
    ax1.set_title('Trend for {} in Category - {}'.format(country, category))
    ax1.set_xticks(cat_data['date'].values)
    ax1.tick_params(labelrotation=60)
    #ax1.annotate('figure pixels',xy=(3, 3), xycoords='data')
    fig.tight_layout()
    
    plt.show()

# %%
# calling the function for countries
combo_plots_3('Canada', 'technology')
